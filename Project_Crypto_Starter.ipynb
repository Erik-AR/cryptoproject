# %%
# Dependencies
import tweepy
import json
import pandas as pd
import csv
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys 
consumer_key = "yUHOWwWG9Pj3C8f21tnm4rWOb"
consumer_secret = "JowHOFRinCn2DOOd7ZP8ToHkU83piXhZ0ZPUopHTW7grDS0XPI"
access_token = "975055841089867776-GRHdjTQ4NuqwZNfevh4L54bxNgiw1Hu"
access_token_secret = "nR7n7Qp5lduLHCH6rSF46gJi8YolN6pRLXnE63lghWc3T"

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# # Get all tweets from home feed
# public_tweets = api.home_timeline()

# # Import CSV file into Data Frame
# popular_tweeters = pd.read_csv("PopularAccounts.csv", dtype=str)

# popular_tweeters.head()

# %%
# Search Term
search_term = "bitcoin"

# Search for all tweets
public_tweets = api.search(search_term,count=2)
public_tweets
counter = 0
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
all_tweets = []

for tweet in public_tweets["statuses"]:
    counter+=1
    print(counter)
    print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    compound = analyzer.polarity_scores(tweet["text"])["compound"]
    pos = analyzer.polarity_scores(tweet["text"])["pos"]
    neu = analyzer.polarity_scores(tweet["text"])["neu"]
    neg = analyzer.polarity_scores(tweet["text"])["neg"]
# Add each value to the appropriate list
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)
    
# Print the Averages
print("compound" + str(compound_list))
print("+ve" + str(positive_list))
print("-ve" + str(negative_list))
print("neutral" + str(neutral_list))

    
    
# len(public_tweets)
# Out:
# 1
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Wed Mar 28 02:35:12 +0000 2018",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     81,
#                     88
#                 ],
#                 "text": "\u30d3\u30c3\u30c8\u30b3\u30a4\u30f3"
#             },
#             {
#                 "indices": [
#                     89,
#                     94
#                 ],
#                 "text": "\u4eee\u60f3\u901a\u8ca8"
#             },
#             {
#                 "indices": [
#                     95,
#                     103
#                 ],
#                 "text": "Bitcoin"
#             },
#             {
#                 "indices": [
#                     104,
#                     108
#                 ],
#                 "text": "BTC"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "bitcoin.waiwainews.net/view/30522",
#                 "expanded_url": "http://bitcoin.waiwainews.net/view/30522",
#                 "indices": [
#                     57,
#                     80
#                 ],
#                 "url": "https://t.co/cURCHzbuUX"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 978822784393527296,
#     "id_str": "978822784393527296",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "ja",
#     "metadata": {
#         "iso_language_code": "ja",
#         "result_type": "recent"
#     },
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://twitter.com/bitcoinmatom\" rel=\"nofollow\">\u30d3\u30c3\u30c8\u30b3\u30a4\u30f3\u53d6\u5f15\u6bd4\u8f03\u30cb\u30e5\u30fc\u30b9\u30a2\u30f3\u30c6\u30ca </a>",
#     "text": "\u8caf\u91d11000\u4e07\u3092\u4eee\u60f3\u901a\u8ca8\u306b\u63db\u3048\u305f\u7537\u306e\u30d6\u30ed\u30b0\u3055\u3093\u306e\u30c6\u30c3\u30af\u30d3\u30e5\u30fc\u30ed\u793e\u304c\u884c\u3063\u305fICO\u300cCOMSA\u300d\u306f\u3069\u3046\u306a\u3063\u3066\u3044\u308b\u306e\u304b https://t.co/cURCHzbuUX #\u30d3\u30c3\u30c8\u30b3\u30a4\u30f3 #\u4eee\u60f3\u901a\u8ca8 #Bitcoin #BTC",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Jun 14 16:31:42 +0000 2017",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "\u30d3\u30c3\u30c8\u30b3\u30a4\u30f3\u306e\u69d8\u3005\u30b5\u30a4\u30c8\u306e\u8a18\u4e8b\u3092\u3055\u3089\u306b\u307e\u3068\u3081\u3066\u304a\u4f1d\u3048\u3057\u3066\u3044\u308b\u30a2\u30f3\u30c6\u30ca\u30b5\u30a4\u30c8\u3067\u3059",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "bitcoin.waiwainews.net",
#                         "expanded_url": "http://bitcoin.waiwainews.net/",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/ciVaHzWDeZ"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 2056,
#         "following": false,
#         "friends_count": 1598,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 875027978639466496,
#         "id_str": "875027978639466496",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "ja",
#         "listed_count": 13,
#         "location": "",
#         "name": "\u30d3\u30c3\u30c8\u30b3\u30a4\u30f3\u53d6\u5f15\u6bd4\u8f03\u30cb\u30e5\u30fc\u30b9\u30a2\u30f3\u30c6\u30ca",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/875027978639466496/1497458196",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/875028811846361089/u4O9pCvf_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/875028811846361089/u4O9pCvf_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "bitcoinmatom",
#         "statuses_count": 8413,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "https://t.co/ciVaHzWDeZ",
#         "utc_offset": null,
#         "verified": false
#     }
# }
# 2
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Wed Mar 28 02:35:11 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "news.bitcoin.com/bank-of-korea-\u2026",
#                 "expanded_url": "https://news.bitcoin.com/bank-of-korea-poll-young-adults-enthusiastic-cryptocurrency/",
#                 "indices": [
#                     74,
#                     97
#                 ],
#                 "url": "https://t.co/ewkNq4AzGF"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 978822780769718272,
#     "id_str": "978822780769718272",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://ifttt.com\" rel=\"nofollow\">IFTTT</a>",
#     "text": "Bank of Korea Poll: 40% of Young Adults Enthusiastic About Cryptocurrency https://t.co/ewkNq4AzGF",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Apr 12 12:12:56 +0000 2016",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Get Satoshis every 1 minute ! #1 Paytoshi Faucet",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "thebigresearch.com",
#                         "expanded_url": "http://thebigresearch.com",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/pXQHq2omtI"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 1,
#         "follow_request_sent": false,
#         "followers_count": 537,
#         "following": false,
#         "friends_count": 322,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 719860850794852353,
#         "id_str": "719860850794852353",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "es",
#         "listed_count": 37,
#         "location": "",
#         "name": "thebigresearch",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/719860850794852353/1460469979",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/719888708770643968/ZBBwJDG7_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/719888708770643968/ZBBwJDG7_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "thebigresearch",
#         "statuses_count": 11790,
#         "time_zone": "Madrid",
#         "translator_type": "none",
#         "url": "https://t.co/pXQHq2omtI",
#         "utc_offset": 7200,
#         "verified": false
#     }
# }
# compound[0.0, 0.4939]
# +ve[0.0, 0.225]
# -ve[0.0, 0.0]
# neutral[1.0, 0.775]
